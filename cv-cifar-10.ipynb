# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import pandas as pd

from tensorflow import keras
from keras.models import Sequential

from tensorflow.keras import regularizers, optimizers

from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import VGG19, efficientnet

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Import Dataset

# %%
from tensorflow.keras.datasets import cifar10
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %% [markdown]
# ### Pre-processsing data

# %% [markdown]
# There are 10 classes that are represented as unique integers and the class element of the data can therefore be one hot encoded.
#
# Secondly the pixel values for each image are unsigned integers between 0 and 250. This is normalised to the range [0,1].

# %%
# One-Hot-Encoding
Y_train = to_categorical(Y_train,10)
Y_test = to_categorical(Y_test,10)

# Normalising
X_train = X_train.astype("float32")/255
X_test = X_test.astype("float32")/255

# %% [markdown]
# In this assignment the test data will not be used for validation, instead a portion (20%) of the training data will be allocated as the validation data.

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Problem 1

# %% [markdown]
# For all models we used a batch_size of 400 and the number of epochs are 40.
#
# Secondly in all our models we use max pooling layers. The reason for this is according to the textbook "Hands-on Machine Learning with Scikit-Learn, Keras & TensorFlow" by Aurélien Géron, even though average pooling layers used to be popular, a shift occurred to max pooling layer as they generally perform better. This is because even though average pooling layers keep more information by computing the mean, max pooling layers preserves only the strongest features so the next layer has a cleaner signal to work with.

# %% [markdown]
# ### Model 1 - Baseline

# %% [markdown]
# This model will be used as the baseline model to compare the rest of the models to.

# %% [markdown]
# A good starting point is a VGG-style architecture. A VGG-style architecture involves stacking convolutional layers with small 3×3 filters followed by a max pooling layer. Each of these stacked convolutional layers and pooling layer pairs are refered to as blocks.
#
# Below as our baseline we implement a 1-block VGG-style architecture.

# %%
model_1 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_1')

model_1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1060138 (4.04 MB)
# Trainable params: 1060138 (4.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_1.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_1 = model_1.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size=400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 7s 21ms/step - loss: 1.9352 - accuracy: 0.3315 - val_loss: 1.5101 - val_accuracy: 0.4636
# Epoch 2/40
# 100/100 [==============================] - 2s 17ms/step - loss: 1.3245 - accuracy: 0.5329 - val_loss: 1.2184 - val_accuracy: 0.5769
# Epoch 3/40
# 100/100 [==============================] - 2s 17ms/step - loss: 1.1207 - accuracy: 0.6101 - val_loss: 1.1503 - val_accuracy: 0.6016
# Epoch 4/40
# 100/100 [==============================] - 2s 17ms/step - loss: 1.0040 - accuracy: 0.6511 - val_loss: 1.0653 - val_accuracy: 0.6334
# Epoch 5/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.9146 - accuracy: 0.6820 - val_loss: 1.0253 - val_accuracy: 0.6486
# Epoch 6/40
# 100/100 [==============================] - 2s 19ms/step - loss: 0.8516 - accuracy: 0.7061 - val_loss: 0.9966 - val_accuracy: 0.6568
# Epoch 7/40
# 100/100 [==============================] - 2s 19ms/step - loss: 0.8061 - accuracy: 0.7219 - val_loss: 0.9798 - val_accuracy: 0.6625
# Epoch 8/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.7464 - accuracy: 0.7414 - val_loss: 0.9998 - val_accuracy: 0.6583
# Epoch 9/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6922 - accuracy: 0.7623 - val_loss: 0.9772 - val_accuracy: 0.6641
# Epoch 10/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6533 - accuracy: 0.7764 - val_loss: 0.9699 - val_accuracy: 0.6710
# Epoch 11/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.6060 - accuracy: 0.7942 - val_loss: 1.0086 - val_accuracy: 0.6670
# Epoch 12/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.5756 - accuracy: 0.8030 - val_loss: 1.0057 - val_accuracy: 0.6704
# Epoch 13/40
# 100/100 [==============================] - 2s 19ms/step - loss: 0.5193 - accuracy: 0.8247 - val_loss: 1.0643 - val_accuracy: 0.6661
# Epoch 14/40
# 100/100 [==============================] - 2s 21ms/step - loss: 0.4946 - accuracy: 0.8315 - val_loss: 1.0492 - val_accuracy: 0.6702
# Epoch 15/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.4471 - accuracy: 0.8513 - val_loss: 1.0803 - val_accuracy: 0.6675
# Epoch 16/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.4056 - accuracy: 0.8672 - val_loss: 1.1106 - val_accuracy: 0.6641
# Epoch 17/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.3822 - accuracy: 0.8749 - val_loss: 1.1441 - val_accuracy: 0.6636
# Epoch 18/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.3398 - accuracy: 0.8914 - val_loss: 1.1861 - val_accuracy: 0.6661
# Epoch 19/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.3194 - accuracy: 0.8982 - val_loss: 1.2293 - val_accuracy: 0.6651
# Epoch 20/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.2857 - accuracy: 0.9104 - val_loss: 1.2810 - val_accuracy: 0.6561
# Epoch 21/40
# 100/100 [==============================] - 2s 21ms/step - loss: 0.2619 - accuracy: 0.9199 - val_loss: 1.3427 - val_accuracy: 0.6593
# Epoch 22/40
# 100/100 [==============================] - 2s 18ms/step - loss: 0.2228 - accuracy: 0.9349 - val_loss: 1.3941 - val_accuracy: 0.6549
# Epoch 23/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1959 - accuracy: 0.9453 - val_loss: 1.4291 - val_accuracy: 0.6591
# Epoch 24/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1734 - accuracy: 0.9534 - val_loss: 1.5351 - val_accuracy: 0.6464
# Epoch 25/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1542 - accuracy: 0.9585 - val_loss: 1.5837 - val_accuracy: 0.6561
# Epoch 26/40
# 100/100 [==============================] - 2s 20ms/step - loss: 0.1427 - accuracy: 0.9620 - val_loss: 1.6578 - val_accuracy: 0.6475
# Epoch 27/40
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1203 - accuracy: 0.9718 - val_loss: 1.6834 - val_accuracy: 0.6543
# Epoch 28/40
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0975 - accuracy: 0.9796 - val_loss: 1.8002 - val_accuracy: 0.6469
# Epoch 29/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1024 - accuracy: 0.9743 - val_loss: 1.8392 - val_accuracy: 0.6472
# Epoch 30/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0847 - accuracy: 0.9816 - val_loss: 1.9009 - val_accuracy: 0.6498
# Epoch 31/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0673 - accuracy: 0.9877 - val_loss: 1.9914 - val_accuracy: 0.6447
# Epoch 32/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0532 - accuracy: 0.9922 - val_loss: 2.0464 - val_accuracy: 0.6463
# Epoch 33/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0476 - accuracy: 0.9934 - val_loss: 2.1488 - val_accuracy: 0.6455
# Epoch 34/40
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0440 - accuracy: 0.9937 - val_loss: 2.1601 - val_accuracy: 0.6454
# Epoch 35/40
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0334 - accuracy: 0.9968 - val_loss: 2.2437 - val_accuracy: 0.6436
# Epoch 36/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0243 - accuracy: 0.9984 - val_loss: 2.3245 - val_accuracy: 0.6429
# Epoch 37/40
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0208 - accuracy: 0.9987 - val_loss: 2.3509 - val_accuracy: 0.6426
# Epoch 38/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0171 - accuracy: 0.9994 - val_loss: 2.4439 - val_accuracy: 0.6469
# Epoch 39/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0144 - accuracy: 0.9996 - val_loss: 2.4889 - val_accuracy: 0.6439
# Epoch 40/40
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0113 - accuracy: 0.9997 - val_loss: 2.5520 - val_accuracy: 0.6442

# %%
pd.DataFrame(history_1.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# **Training Loss:** Continuously decreases across epochs, reaching a minimum of 0.0113.
#
# **Training Accuracy:** Continuously increases across epochs, reaching nearly 100% by the final epochs.
#
# **Validation Loss:** Initially decreases but starts increasing significantly from around epoch 10 onward, indicating overfitting.
#
# **Validation Accuracy:** Remains relatively stable after the initial increase, eventually starting to drop.
#
# From this we can conclude that a clear overfitting pattern is evident, since training loss decreases significantly, while validation loss starts increasing. Another indication is the validation accuracy does not improve and even declines slightly, which confirms overfitting.
#
# The model obtained: Final Validation Accuracy: 64.4% and Best Validation Accuracy: 67.1% (Epoch 10).

# %% [markdown]
# ### Model 2

# %% [markdown]
# 2-block VGG-style architecture.

# %%
model_2 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_2')

model_2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 128)               524416
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 591274 (2.26 MB)
# Trainable params: 591274 (2.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_2.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_2 = model_2.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size = 400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 6s 31ms/step - loss: 1.7565 - accuracy: 0.3764 - val_loss: 1.3897 - val_accuracy: 0.5004
# Epoch 2/40
# 100/100 [==============================] - 3s 26ms/step - loss: 1.2638 - accuracy: 0.5503 - val_loss: 1.1828 - val_accuracy: 0.5833
# Epoch 3/40
# 100/100 [==============================] - 3s 27ms/step - loss: 1.0767 - accuracy: 0.6202 - val_loss: 1.0337 - val_accuracy: 0.6380
# Epoch 4/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.9307 - accuracy: 0.6767 - val_loss: 0.9472 - val_accuracy: 0.6723
# Epoch 5/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.8405 - accuracy: 0.7075 - val_loss: 0.9641 - val_accuracy: 0.6643
# Epoch 6/40
# 100/100 [==============================] - 3s 27ms/step - loss: 0.7583 - accuracy: 0.7371 - val_loss: 0.8752 - val_accuracy: 0.6975
# Epoch 7/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.6881 - accuracy: 0.7609 - val_loss: 0.8826 - val_accuracy: 0.6968
# Epoch 8/40
# 100/100 [==============================] - 3s 27ms/step - loss: 0.6234 - accuracy: 0.7855 - val_loss: 0.8590 - val_accuracy: 0.7034
# Epoch 9/40
# 100/100 [==============================] - 3s 30ms/step - loss: 0.5750 - accuracy: 0.8011 - val_loss: 0.8778 - val_accuracy: 0.6980
# Epoch 10/40
# 100/100 [==============================] - 3s 29ms/step - loss: 0.5052 - accuracy: 0.8265 - val_loss: 0.8946 - val_accuracy: 0.7073
# Epoch 11/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.4596 - accuracy: 0.8416 - val_loss: 0.9127 - val_accuracy: 0.7101
# Epoch 12/40
# 100/100 [==============================] - 3s 27ms/step - loss: 0.4057 - accuracy: 0.8605 - val_loss: 0.9348 - val_accuracy: 0.7067
# Epoch 13/40
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3725 - accuracy: 0.8712 - val_loss: 0.9232 - val_accuracy: 0.7180
# Epoch 14/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 2.1454 - val_accuracy: 0.6990
# Epoch 34/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0413 - accuracy: 0.9868 - val_loss: 2.1585 - val_accuracy: 0.6994
# Epoch 35/40
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0456 - accuracy: 0.9848 - val_loss: 2.1997 - val_accuracy: 0.7006
# Epoch 36/40
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0614 - accuracy: 0.9784 - val_loss: 2.2228 - val_accuracy: 0.6975
# Epoch 37/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 2.2724 - val_accuracy: 0.6959
# Epoch 38/40
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 2.2050 - val_accuracy: 0.6963
# Epoch 39/40
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0354 - accuracy: 0.9879 - val_loss: 2.3141 - val_accuracy: 0.7013
# Epoch 40/40
# 100/100 [==============================] - 3s 28ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 2.3440 - val_accuracy: 0.6987

# %%
pd.DataFrame(history_2.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# **Training Loss:** Continuously decreases across epochs, reaching a minimum of 0.0215.
#
# **Training Accuracy:** Continuously increases across epochs, reaching nearly 100% by the final epochs.
#
# **Validation Loss:** Initially decreases but starts increasing significantly from around epoch 7 onward, indicating overfitting.
#
# **Validation Accuracy:** Remains relatively stable after the initial increase, eventually starting to drop.
#
# From this we can conclude that a clear overfitting pattern is evident, since training loss decreases significantly, while validation loss starts increasing. Another indication is the validation accuracy does not improve and even declines slightly, which confirms overfitting.
#
# The model obtained: Final Validation Accuracy: 69.87% and Best Validation Accuracy: 71.81% (Epoch 14). Model 2 therefore performed better than Model 1, but overfitting is still evident.

# %% [markdown]
# ### Model 3

# %% [markdown]
# 3-block VGG-style architecture.

# %%
model_3 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_3')

model_3.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_3.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_3 = model_3.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size = 400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 7s 38ms/step - loss: 1.7851 - accuracy: 0.3496 - val_loss: 1.4203 - val_accuracy: 0.4877
# Epoch 2/40
# 100/100 [==============================] - 4s 35ms/step - loss: 1.3119 - accuracy: 0.5311 - val_loss: 1.2080 - val_accuracy: 0.5712
# Epoch 3/40
# 100/100 [==============================] - 3s 33ms/step - loss: 1.0698 - accuracy: 0.6234 - val_loss: 1.1160 - val_accuracy: 0.6079
# Epoch 4/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.8992 - accuracy: 0.6855 - val_loss: 0.9557 - val_accuracy: 0.6609
# Epoch 5/40
# 100/100 [==============================] - 3s 35ms/step - loss: 0.7792 - accuracy: 0.7270 - val_loss: 0.8714 - val_accuracy: 0.6941
# Epoch 6/40
# 100/100 [==============================] - 3s 35ms/step - loss: 0.6761 - accuracy: 0.7646 - val_loss: 0.8246 - val_accuracy: 0.7107
# Epoch 7/40
# 100/100 [==============================] - 3s 35ms/step - loss: 0.5812 - accuracy: 0.7994 - val_loss: 0.7929 - val_accuracy: 0.7282
# Epoch 8/40
# 100/100 [==============================] - 4s 36ms/step - loss: 0.4955 - accuracy: 0.8288 - val_loss: 0.8341 - val_accuracy: 0.7203
# Epoch 9/40
# 100/100 [==============================] - 4s 37ms/step - loss: 0.4218 - accuracy: 0.8555 - val_loss: 0.8635 - val_accuracy: 0.7271
# Epoch 10/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3501 - accuracy: 0.8790 - val_loss: 0.8519 - val_accuracy: 0.7420
# Epoch 11/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.2841 - accuracy: 0.9018 - val_loss: 0.9480 - val_accuracy: 0.7316
# Epoch 12/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.2300 - accuracy: 0.9201 - val_loss: 0.9862 - val_accuracy: 0.7222
# Epoch 13/40
# 100/100 [==============================] - 3s 35ms/step - loss: 0.1856 - accuracy: 0.9361 - val_loss: 1.1073 - val_accuracy: 0.7303
# Epoch 14/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.1328 - accuracy: 0.9551 - val_loss: 1.1937 - val_accuracy: 0.7343
# Epoch 15/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.1116 - accuracy: 0.9612 - val_loss: 1.1861 - val_accuracy: 0.7283
# Epoch 16/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0886 - accuracy: 0.9708 - val_loss: 1.3793 - val_accuracy: 0.7352
# Epoch 17/40
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0721 - accuracy: 0.9761 - val_loss: 1.4066 - val_accuracy: 0.7266
# Epoch 18/40
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0725 - accuracy: 0.9751 - val_loss: 1.4679 - val_accuracy: 0.7410
# Epoch 19/40
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0755 - accuracy: 0.9727 - val_loss: 1.4397 - val_accuracy: 0.7355
# Epoch 20/40
# 100/100 [==============================] - 4s 36ms/step - loss: 0.
history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# **Training Loss:** Continuously decreases across epochs, reaching a minimum of 0.0520.
#
# **Training Accuracy:** Continuously increases across epochs, reaching nearly 100% by the final epochs.
#
# **Validation Loss:** Initially decreases but starts increasing significantly from around epoch 7 onward, indicating overfitting.
#
# **Validation Accuracy:** Remains relatively stable after the initial increase, eventually starting to drop.
#
# From this we can conclude that a clear overfitting pattern is evident, since training loss decreases significantly, while validation loss starts increasing. Another indication is the validation accuracy does not improve and even declines slightly, which confirms overfitting.
#
# The model obtained: Final Validation Accuracy: 73.13% and Best Validation Accuracy: 74.20% (Epoch 37). Model 3 therefore performed better than Model 1 and Model 2, but overfitting is still evident.

# %% [markdown]
# It can be seen that increasing the number of blocks in the VGG-style architecture does increase the validation accuracy of the model, but all the models strugle with overfitting. Thus in order to improve the model performance we need to combat the overfitting.

# %% [markdown]
# ### Model 4

# %% [markdown]
# 3-block VGG-style architecture with dropout to combat overfitting.

# %%
model_4 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_4')

model_4.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_9 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 64)        18496
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_10 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_4 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_11 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dense_8 (Dense)             (None, 128)               262272
#
#  dense_9 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_4.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_4 = model_4.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size = 400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 8s 48ms/step - loss: 2.1771 - accuracy: 0.1918 - val_loss: 1.9288 - val_accuracy: 0.2710
# Epoch 2/40
# 100/100 [==============================] - 4s 43ms/step - loss: 1.7189 - accuracy: 0.3651 - val_loss: 1.5205 - val_accuracy: 0.4507
# Epoch 3/40
history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# **Training Loss:** Continuously decreases across epochs, reaching a minimum of 0.2460.
#
# **Training Accuracy:** Continuously increases across epochs, reaching nearly 91.30% by the final epochs.
#
# **Validation Loss:** Initially decreases, but stabilises around epoch 15 before gradually increasing again.
#
# **Validation Accuracy:** Remains relatively stable after the initial increase.
#
# The incorporation of dropout increased training loss slightly but maintained a high training accuracy. This indicates that the regularisation effect of dropout successfully combats overfitting without heavily impacting performance.
#
# The model obtained: Final Validation Accuracy: 80.19% and Best Validation Accuracy: 80.69% (Epoch 35). Model 4 outperformed all the other Models, but even though dropout has improved overfitting drastically, it is still evident.

# %% [markdown]
# ### Model 5

# %% [markdown]
# A second regularisation technique to test is L2 weight regularisation. This will be implemented in Model 5 below.

# %%
model_5 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_regularizer=l2(0.001),  kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=64, kernel_size=(3,3), kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(filters=128, kernel_size=(3,3), kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3,3), kernel_regularizer=l2(0.001), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu',kernel_regularizer=l2(0.001), kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_5')

model_5.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_5.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_5 = model_5.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size = 400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 10s 34ms/step - loss: 2.6181 - accuracy: 0.3478 - val_loss: 2.1179 - val_accuracy: 0.4611
# Epoch 2/40
# 100/100 [==============================] - 3s 29ms/step - loss: 1.9512 - accuracy: 0.5104 - val_loss: 1.7544 - val_accuracy: 0.5707
# Epoch 3/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.6699 - accuracy: 0.5897 - val_loss: 1.6176 - val_accuracy: 0.6063
# Epoch 4/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.5112 - accuracy: 0.6358 - val_loss: 1.4372 - val_accuracy: 0.6564
# Epoch 5/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.3649 - accuracy: 0.6800 - val_loss: 1.3886 - val_accuracy: 0.6686
# Epoch 6/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.2588 - accuracy: 0.7142 - val_loss: 1.3187 - val_accuracy: 0.6883
# Epoch 7/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1874 - accuracy: 0.7352 - val_loss: 1.2422 - val_accuracy: 0.7093
# Epoch 8/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.1036 - accuracy: 0.7605 - val_loss: 1.1938 - val_accuracy: 0.7323
# Epoch 9/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.0477 - accuracy: 0.7793 - val_loss: 1.1624 - val_accuracy: 0.7404
# Epoch 10/40
# 100/100 [==============================] - 3s 30ms/step - loss: 1.0001 - accuracy: 0.7933 - val_loss: 1.1441 - val_accuracy: 0.7437
# Epoch 11/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.9457 - accuracy: 0.8136 - val_loss: 1.2025 - val_accuracy: 0.7294
# Epoch 12/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.8992 - accuracy: 0.8270 - val_loss: 1.1288 - val_accuracy: 0.7514
# Epoch 13/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.8587 - accuracy: 0.8429 - val_loss: 1.1673 - val_accuracy: 0.7513
# Epoch 14/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.8302 - accuracy: 0.8519 - val_loss: 1.1505 - val_accuracy: 0.7506
# Epoch 15/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.8058 - accuracy: 0.8627 - val_loss: 1.1681 - val_accuracy: 0.7519
# Epoch 16/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.7520 - accuracy: 0.8826 - val_loss: 1.2105 - val_accuracy: 0.7498
# Epoch 17/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.7365 - accuracy: 0.8881 - val_loss: 1.2225 - val_accuracy: 0.7499
# Epoch 18/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.7025 - accuracy: 0.9020 - val_loss: 1.2424 - val_accuracy: 0.7544
# Epoch 19/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.6743 - accuracy: 0.9123 - val_loss: 1.2679 - val_accuracy: 0.7492
# Epoch 20/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.6571 - accuracy: 0.9195 - val_loss: 1.2771 - val_accuracy: 0.7587
# Epoch 21/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.6180 - accuracy: 0.9338 - val_loss: 1.2911 - val_accuracy: 0.7624
# Epoch 22/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.6064 - accuracy: 0.9383 - val_loss: 1.3541 - val_accuracy: 0.7468
# Epoch 23/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5961 - accuracy: 0.9409 - val_loss: 1.2819 - val_accuracy: 0.7635
# Epoch 24/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5809 - accuracy: 0.9472 - val_loss: 1.3790 - val_accuracy: 0.7463
# Epoch 25/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5704 - accuracy: 0.9495 - val_loss: 1.4939 - val_accuracy: 0.7315
# Epoch 26/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5633 - accuracy: 0.9510 - val_loss: 1.4204 - val_accuracy: 0.7374
# Epoch 27/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5533 - accuracy: 0.9546 - val_loss: 1.4385 - val_accuracy: 0.7540
# Epoch 28/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5416 - accuracy: 0.9579 - val_loss: 1.4330 - val_accuracy: 0.7567
# Epoch 29/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5504 - accuracy: 0.9556 - val_loss: 1.4806 - val_accuracy: 0.7419
# Epoch 30/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5253 - accuracy: 0.9631 - val_loss: 1.4823 - val_accuracy: 0.7425
# Epoch 31/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5275 - accuracy: 0.9615 - val_loss: 1.4618 - val_accuracy: 0.7494
# Epoch 32/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4980 - accuracy: 0.9719 - val_loss: 1.5016 - val_accuracy: 0.7576
# Epoch 33/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5183 - accuracy: 0.9614 - val_loss: 1.4786 - val_accuracy: 0.7489
# Epoch 34/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.5055 - accuracy: 0.9653 - val_loss: 1.4824 - val_accuracy: 0.7528
# Epoch 35/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4914 - accuracy: 0.9699 - val_loss: 1.4814 - val_accuracy: 0.7570
# Epoch 36/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4958 - accuracy: 0.9659 - val_loss: 1.4556 - val_accuracy: 0.7560
# Epoch 37/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4863 - accuracy: 0.9693 - val_loss: 1.5113 - val_accuracy: 0.7491
# Epoch 38/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.4788 - accuracy: 0.9710 - val_loss: 1.4285 - val_accuracy: 0.7525
# Epoch 39/40
# 100/100 [==============================] - 3s 32ms/step - loss: 0.4902 - accuracy: 0.9660 - val_loss: 1.4281 - val_accuracy: 0.7490
# Epoch 40/40
# 100/100 [==============================] - 3s 31ms/step - loss: 0.4979 - accuracy: 0.9631 - val_loss: 1.4217 - val_accuracy: 0.7502

# %%
pd.DataFrame(history_5.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# **Training Loss:** Continuously decreases across epochs, reaching a minimum of 0.4979.
#
# **Training Accuracy:** Continuously increases across epochs, reaching nearly 96.31% by the final epochs.
#
# **Validation Loss:** Initially decreases, but stabilises around epoch 10 before increasing again.
#
# **Validation Accuracy:** Remains relatively stable after the initial increase.
#
# The incorporation of L2-regularisation increased training loss slightly but maintained a high training accuracy. This indicates that the regularisation effect of L2-regularisation successfully combats overfitting without heavily impacting performance.
#
# The model obtained: Final Validation Accuracy: 75.02% and Best Validation Accuracy: 76.35% (Epoch 23). Model 5 outperformed all the other Models except for Model 4, but even though L2-regularisation has improved overfitting drastically, it is still evident.
#
# Both dropout and L2-regularisation seem to combat overfitting equally well, but since Model 4 had a better Best Validation Accuaracy, we will use this model and incorporate early stopping in attempt to completely overcome overfitting.

# %% [markdown]
# ### Model 6

# %% [markdown]
# This model will make use of dropout and early stopping in atempt to overcome overfitting.

# %%
model_6 =  Sequential([
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu', input_shape=(32,32,3)),
    Conv2D(filters=32, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=64, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    Conv2D(filters=128, kernel_size=(3,3), kernel_initializer='he_uniform', padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax'),
], name='model_6')

model_6.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 128)               262272
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 550570 (2.10 MB)
# Trainable params: 550570 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopper = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# %%
model_6.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history_6 = model_6.fit(X_train, Y_train, epochs = 40, verbose=1, validation_data=(X_val,Y_val), batch_size = 400, callbacks=[early_stopper])
# Out:
# Epoch 1/40
# 100/100 [==============================] - 8s 47ms/step - loss: 2.1040 - accuracy: 0.2142 - val_loss: 1.7333 - val_accuracy: 0.3588
# Epoch 2/40
# 100/100 [==============================] - 4s 42ms/step - loss: 1.5859 - accuracy: 0.4144 - val_loss: 1.4504 - val_accuracy: 0.4754
# Epoch 3/40
# 100/100 [==============================] - 4s 44ms/step - loss: 1.3682 - accuracy: 0.4999 - val_loss: 1.2410 - val_accuracy: 0.5595
# Epoch 4/40
# 100/100 [==============================] - 5s 46ms/step - loss: 1.2202 - accuracy: 0.5629 - val_loss: 1.1233 - val_accuracy: 0.5931
# Epoch 5/40
# 100/100 [==============================] - 4s 42ms/step - loss: 1.0956 - accuracy: 0.6062 - val_loss: 1.0211 - val_accuracy: 0.6402
# Epoch 6/40
# Epoch 26/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3995 - accuracy: 0.8583 - val_loss: 0.6210 - val_accuracy: 0.7965
# Epoch 27/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3780 - accuracy: 0.8644 - val_loss: 0.6080 - val_accuracy: 0.8073
# Epoch 28/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3696 - accuracy: 0.8672 - val_loss: 0.5998 - val_accuracy: 0.8143
# Epoch 29/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3588 - accuracy: 0.8709 - val_loss: 0.6034 - val_accuracy: 0.8117
# Epoch 30/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3463 - accuracy: 0.8752 - val_loss: 0.6156 - val_accuracy: 0.8119
# Epoch 31/40
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3335 - accuracy: 0.8802 - val_loss: 0.6217 - val_accuracy: 0.8101
# Epoch 32/40
#  99/100 [============================>.] - ETA: 0s - loss: 0.3263 - accuracy: 0.8820Restoring model weights from the end of the best epoch: 22.
# 100/100 [==============================] - 4s 41ms/step - loss: 0.3259 - accuracy: 0.8822 - val_loss: 0.6169 - val_accuracy: 0.8140
# Epoch 32: early stopping

# %%
pd.DataFrame(history_6.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2)
# Out:
# (0.0, 2.0)

# %% [markdown]
# As can be seen, by incorporating dropout and early stopping we removed overfitting. This model outperformed all the other models with Validation accuracy of 80.66% and Validation loss of 0.5837.
#
# Therefore Model 6 is our chosen model and will now be evaluated on the test set.

# %% [markdown]
# ### Model 6 Evaluation.

# %%
test_loss, test_accuracy = model_6.evaluate(X_test, Y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.5920 - accuracy: 0.7970
# Test Loss: 0.5920141339302063
# Test Accuracy: 0.796999990940094

# %% [markdown]
# Model 6 yielded a test accuracy of roughly 80%. This is an excellent result and is an indication of how well our model generalises.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ### Model 7

# %% [markdown]
# We will make use of the VGG model available in keras. The reason for this is this model also makes use of the VGG architecture described earlier. It will be intersting to see how increasing the number of blocks as in the VGG model affects the models accuracy.

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
base_model.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 32, 32, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 32, 32, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 16, 16, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 16, 16, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 16, 16, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 8, 8, 128)         0
#
#  block3_conv1 (Conv2D)       (None, 8, 8, 256)         295168
#
#  block3_conv2 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv3 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_conv4 (Conv2D)       (None, 8, 8, 256)         590080
#
#  block3_pool (MaxPooling2D)  (None, 4, 4, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 4, 4, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 2, 2, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 20024384 (76.39 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %% [markdown]
# The VGG19 network, designed for ImageNet, expects input images of size 224x224 pixels. However, CIFAR-10 images are 32x32 pixels. By specifying input_shape=(32, 32, 3), you are explicitly informing the model to adjust its initial convolutional layers to accept smaller images. Without this adjustment, the model would not accept the CIFAR-10 image size as input.

# %%
model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dense(10, activation='softmax')
])

# %%
model.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history = model.fit(X_train, Y_train, epochs=40, verbose=1, validation_data=(X_val, Y_val), batch_size=400)
# Out:
# Epoch 1/40
# 100/100 [==============================] - 8s 67ms/step - loss: 1.6762 - accuracy: 0.4186 - val_loss: 1.4439 - val_accuracy: 0.4978
# Epoch 2/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.3721 - accuracy: 0.5247 - val_loss: 1.3476 - val_accuracy: 0.5255
# Epoch 3/40
# 100/100 [==============================] - 6s 62ms/step - loss: 1.2952 - accuracy: 0.5524 - val_loss: 1.3099 - val_accuracy: 0.5369
# Epoch 4/40
# 100/100 [==============================] - 6s 63ms/step - loss: 1.2478 - accuracy: 0.5681 - val_loss: 1.2720 - val_accuracy: 0.5522
# Epoch 5/40
# 100/100 [==============================] - 6s 63ms/step - loss: 1.2197 - accuracy: 0.5756 - val_loss: 1.2537 - val_accuracy: 0.5627
# Epoch 6/40
# 100/100 [==============================] - 6s 63ms/step - loss: 1.1967 - accuracy: 0.5843 - val_loss: 1.2306 - val_accuracy: 0.5697
# Epoch 7/40
# 100/100 [==============================] - 6s 63ms/step - loss: 1.1718 - accuracy: 0.5941 - val_loss: 1.2281 - val_accuracy: 0.5692
# Epoch 8/40
# 100/100 [==============================] - 6s 62ms/step - loss: 1.1572 - accuracy: 0.5979 - val_loss: 1.2082 - val_accuracy: 0.5768
# Epoch 9/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.1420 - accuracy: 0.6023 - val_loss: 1.2076 - val_accuracy: 0.5758
# Epoch 10/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.1277 - accuracy: 0.6109 - val_loss: 1.2097 - val_accuracy: 0.5732
# Epoch 11/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.1161 - accuracy: 0.6123 - val_loss: 1.1947 - val_accuracy: 0.5817
# Epoch 12/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.1071 - accuracy: 0.6160 - val_loss: 1.1954 - val_accuracy: 0.5777
# Epoch 13/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0940 - accuracy: 0.6205 - val_loss: 1.1936 - val_accuracy: 0.5819
# Epoch 14/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0863 - accuracy: 0.6227 - val_loss: 1.1780 - val_accuracy: 0.5848
# Epoch 15/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0737 - accuracy: 0.6280 - val_loss: 1.1799 - val_accuracy: 0.5878
# Epoch 16/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0646 - accuracy: 0.6300 - val_loss: 1.1723 - val_accuracy: 0.5894
# Epoch 17/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0577 - accuracy: 0.6313 - val_loss: 1.1685 - val_accuracy: 0.5903
# Epoch 18/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0490 - accuracy: 0.6343 - val_loss: 1.1684 - val_accuracy: 0.5903
# Epoch 19/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0406 - accuracy: 0.6401 - val_loss: 1.1629 - val_accuracy: 0.5949
# Epoch 20/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0353 - accuracy: 0.6401 - val_loss: 1.1646 - val_accuracy: 0.5935
# Epoch 21/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0291 - accuracy: 0.6409 - val_loss: 1.1670 - val_accuracy: 0.5906
# Epoch 22/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0190 - accuracy: 0.6453 - val_loss: 1.1588 - val_accuracy: 0.5917
# Epoch 23/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0108 - accuracy: 0.6473 - val_loss: 1.1729 - val_accuracy: 0.5881
# Epoch 24/40
# 100/100 [==============================] - 6s 61ms/step - loss: 1.0028 - accuracy: 0.6499 - val_loss: 1.1552 - val_accuracy: 0.5965
# Epoch 25/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9978 - accuracy: 0.6530 - val_loss: 1.1589 - val_accuracy: 0.5960
# Epoch 26/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9924 - accuracy: 0.6537 - val_loss: 1.1614 - val_accuracy: 0.5914
# Epoch 27/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9871 - accuracy: 0.6551 - val_loss: 1.1596 - val_accuracy: 0.5968
# Epoch 28/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9785 - accuracy: 0.6592 - val_loss: 1.1705 - val_accuracy: 0.5908
# Epoch 29/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9744 - accuracy: 0.6605 - val_loss: 1.1597 - val_accuracy: 0.5945
# Epoch 30/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9658 - accuracy: 0.6653 - val_loss: 1.1650 - val_accuracy: 0.5952
# Epoch 31/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9565 - accuracy: 0.6672 - val_loss: 1.1592 - val_accuracy: 0.5951
# Epoch 32/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9535 - accuracy: 0.6679 - val_loss: 1.1556 - val_accuracy: 0.5966
# Epoch 33/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9472 - accuracy: 0.6692 - val_loss: 1.1508 - val_accuracy: 0.6002
# Epoch 34/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9411 - accuracy: 0.6716 - val_loss: 1.1610 - val_accuracy: 0.5990
# Epoch 35/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9337 - accuracy: 0.6770 - val_loss: 1.1561 - val_accuracy: 0.5956
# Epoch 36/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9284 - accuracy: 0.6778 - val_loss: 1.1586 - val_accuracy: 0.5993
# Epoch 37/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9227 - accuracy: 0.6788 - val_loss: 1.1565 - val_accuracy: 0.6001
# Epoch 38/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9179 - accuracy: 0.6807 - val_loss: 1.1708 - val_accuracy: 0.5960
# Epoch 39/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9123 - accuracy: 0.6834 - val_loss: 1.1657 - val_accuracy: 0.5989
# Epoch 40/40
# 100/100 [==============================] - 6s 61ms/step - loss: 0.9074 - accuracy: 0.6847 - val_loss: 1.1611 - val_accuracy: 0.5994

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 3)
# Out:
# (0.0, 3.0)

# %% [markdown]
# As you can see this model has definitely not improved on Model 6. A reason for this can be the fact that the convolutional layers are not being trained.
#
# As for training time, I do not see a significant improvement in training time when using the pre-trained model. This might be becuase in this report we are using Google Colabs T4 GPU, this is a very powerfull GPU for training deep learning models (As you can see in the training times provided in the Epochs).

# %% [markdown]
# ### Model 8

# %% [markdown]
# To try and improve on the Model 7 that made use of transfer learning, we will set the last 4 convolution layers as trainable. We will also add early stopping and dropout to the Model to mitigate overfitting.

# %%
early_stopper = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode='min',
    restore_best_weights=True
)

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

# %%
model = Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu', kernel_initializer='he_uniform'),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

# %%
model.compile(loss ="categorical_crossentropy", optimizer ="adam", metrics =["accuracy"])

# %%
history = model.fit(X_train, Y_train, epochs=40, verbose=1, validation_data=(X_val, Y_val), batch_size=400, callbacks=[early_stopper])
# Out:
# Epoch 1/40
# 100/100 [==============================] - 10s 84ms/step - loss: 1.6638 - accuracy: 0.3979 - val_loss: 1.1688 - val_accuracy: 0.5980
# Epoch 2/40
# 100/100 [==============================] - 8s 79ms/step - loss: 1.0805 - accuracy: 0.6317 - val_loss: 0.9603 - val_accuracy: 0.6714
# Epoch 3/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.9368 - accuracy: 0.6819 - val_loss: 0.9274 - val_accuracy: 0.6753
# Epoch 4/40
# 100/100 [==============================] - 8s 81ms/step - loss: 0.8347 - accuracy: 0.7140 - val_loss: 0.9115 - val_accuracy: 0.6912
# Epoch 5/40
# 100/100 [==============================] - 8s 81ms/step - loss: 0.7616 - accuracy: 0.7371 - val_loss: 0.8828 - val_accuracy: 0.6963
# Epoch 6/40
# 100/100 [==============================] - 8s 80ms/step - loss: 0.7062 - accuracy: 0.7596 - val_loss: 0.8794 - val_accuracy: 0.6974
# Epoch 7/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.6488 - accuracy: 0.7752 - val_loss: 0.9355 - val_accuracy: 0.7012
# Epoch 8/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.5808 - accuracy: 0.8004 - val_loss: 0.8672 - val_accuracy: 0.7105
# Epoch 9/40
# 100/100 [==============================] - 8s 78ms/step - loss: 0.5212 - accuracy: 0.8202 - val_loss: 0.9082 - val_accuracy: 0.7161
# Epoch 10/40
# 100/100 [==============================] - 8s 78ms/step - loss: 0.4644 - accuracy: 0.8411 - val_loss: 0.9248 - val_accuracy: 0.7103
# Epoch 11/40
# 100/100 [==============================] - 8s 78ms/step - loss: 0.4437 - accuracy: 0.8464 - val_loss: 1.0195 - val_accuracy: 0.7090
# Epoch 12/40
# 100/100 [==============================] - 8s 78ms/step - loss: 0.3761 - accuracy: 0.8684 - val_loss: 1.0487 - val_accuracy: 0.7045
# Epoch 13/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.3379 - accuracy: 0.8844 - val_loss: 1.0646 - val_accuracy: 0.7075
# Epoch 14/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2982 - accuracy: 0.8975 - val_loss: 1.1588 - val_accuracy: 0.6989
# Epoch 15/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2522 - accuracy: 0.9147 - val_loss: 1.2324 - val_accuracy: 0.7019
# Epoch 16/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2364 - accuracy: 0.9175 - val_loss: 1.2552 - val_accuracy: 0.7044
# Epoch 17/40
# 100/100 [==============================] - 8s 79ms/step - loss: 0.2117 - accuracy: 0.9283 - val_loss: 1.4178 - val_accuracy: 0.7040
# Epoch 18/40
# 100/100 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9373Restoring model weights from the end of the best epoch: 8.
# 100/100 [==============================] - 8s 80ms/step - loss: 0.1817 - accuracy: 0.9373 - val_loss: 1.4107 - val_accuracy: 0.7080
# Epoch 18: early stopping

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 3)
# Out:
# (0.0, 3.0)

# %%
test_loss, test_accuracy = model.evaluate(X_test, Y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.8848 - accuracy: 0.7111
# Test Loss: 0.8848167061805725
# Test Accuracy: 0.7110999822616577

# %% [markdown]
# By allowing some of the convolutional layers to train and by adding dropout and early stopping, we have definetly improved on Model 7.
#
# Even though we improved on Model 7, this Model does not outperform Model 6.

# %% [markdown]
# **To conclude:**
#
# Reasons why the VGG19 model might not perform well on the CIFAR-10 dataset are:
#
#
# *   VGG19 has a deep and complex architecture, with over 140 million parameters, this leads to overfitting on smaller datasets due to its limited number of training examples
# *    Input size mismatch, as it is designed for larger ImageNet images of 224x224, while CIFAR-10 images are only 32x32.
